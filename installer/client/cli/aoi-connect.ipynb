# %%
from dotenv import load_dotenv
from pydub import AudioSegment
from openai import OpenAI, AzureOpenAI, APIConnectionError
import os
import argparse

# %%
deployment_name='gpt-4o'
# deployment_name='chat'

# %%
api_key = os.environ["AZURE_OPENAI_API_KEY"]
client = AzureOpenAI(api_key=api_key)
client.azure_endpoint = os.environ.get("AZURE_OPENAI_ENDPOINT")
client.api_version = os.environ.get("AZURE_OPENAI_API_VERSION")
client.model = deployment_name
# client.azure_deployment = deployment_name # azure_deployment not defined

# %%
# For all possible arguments see https://platform.openai.com/docs/api-reference/chat-completions/create
response = client.chat.completions.create(
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Knock knock."},
        {"role": "assistant", "content": "Who's there?"},
        {"role": "user", "content": "Orange."},
    ],
    temperature=0,
)

print(f"{response.choices[0].message.role}: {response.choices[0].message.content}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 2
#       1 # For all possible arguments see https://platform.openai.com/docs/api-reference/chat-completions/create
# ----> 2 response = client.chat.completions.create(
#       3     messages=[
#       4         {"role": "system", "content": "You are a helpful assistant."},
#       5         {"role": "user", "content": "Knock knock."},
#       6         {"role": "assistant", "content": "Who's there?"},
#       7         {"role": "user", "content": "Orange."},
#       8     ],
#       9     temperature=0,
#      10 )
#      12 print(f"{response.choices[0].message.role}: {response.choices[0].message.content}")
#
# File /opt/Repos/github/fabric/.venv/lib/python3.11/site-packages/openai/_utils/_utils.py:273, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     271         else:
# ...

# %%
start_phrase = 'Write a tagline for an ice cream shop. '
response = client.chat.completions.create(
    model="chat",
    messages=[
        {"role": "system", "content": "Write a tagline for an ice cream shop. "}
    ]
)

# print(start_phrase+response.choices[0].text)

print(f"{response.choices[0].message.role}: {response.choices[0].message.content}")
# Out:
# assistant: "Ice Cream Bliss: Where Every Scoop is a Dream"
